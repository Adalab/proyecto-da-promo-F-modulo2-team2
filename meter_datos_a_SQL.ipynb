# %%
# !pip install mysql-connector-python
# !pip install mysql-connector
# Out:
# Requirement already satisfied: mysql-connector-python in /Users/marta/anaconda3/envs/adalabenv/lib/python3.10/site-packages (8.2.0)
# Requirement already satisfied: protobuf<=4.21.12,>=4.21.1 in /Users/marta/anaconda3/envs/adalabenv/lib/python3.10/site-packages (from mysql-connector-python) (4.21.12)
# Requirement already satisfied: mysql-connector in /Users/marta/anaconda3/envs/adalabenv/lib/python3.10/site-packages (2.2.9)

# %%
import pandas as pd

# %%
df_premios = pd.read_csv("PREMIOS_OSCAR.csv", index_col = 0)
df_premios.head()
# Out:
#    employee_number  last_name first_name extension  \
# 0             1002     Murphy      Diane     x5800
# 1             1056  Patterson       Mary     x4611
# 2             1076   Firrelli       Jeff     x9273
# 3             1088  Patterson    William     x4871
# 4             1102     Bondur     Gerard     x5408
#
#                              email  office_code  reports_to  \
# 0     dmurphy@classicmodelcars.com            1         NaN
# 1   mpatterso@classicmodelcars.com            1      1002.0
# 2   jfirrelli@classicmodelcars.com            1      1002.0
# 3  wpatterson@classicmodelcars.com            6      1056.0
# 4     gbondur@classicmodelcars.com            4      1056.0
#
#               job_title
# 0             President
# 1              VP Sales
# 2          VP Marketing
# 3  Sales Manager (APAC)
# 4   Sale Manager (EMEA)

# %%
lista_tuplas_premios = [tuple(x) for x in df_premios.values]
lista_tuplas_premios
# Out:
# [(1002,
#   'Murphy',
#   'Diane',
#   'x5800',
#   'dmurphy@classicmodelcars.com',
#   1,
#   nan,
#   'President'),
#  (1056,
#   'Patterson',
#   'Mary',
#   'x4611',
#   'mpatterso@classicmodelcars.com',
#   1,
#   1002.0,
#   'VP Sales'),
#  (1076,
#   'Firrelli',
#   'Jeff',
#   'x9273',
#   'jfirrelli@classicmodelcars.com',
#   1,
#   1002.0,
#   'VP Marketing'),
#  (1088,
#   'Patterson',
#   'William',
#   'x4871',
#   'wpatterson@classicmodelcars.com',
#   6,
#   1056.0,
#   'Sales Manager (APAC)'),
#  (1102,
#   'Bondur',
#   'Gerard',
#   'x5408',
#   'gbondur@classicmodelcars.com',
#   4,
#   1056.0,
#   'Sale Manager (EMEA)'),
#  (1143,
#   'Bow',
#   'Anthony',
#   'x5428',
#   'abow@classicmodelcars.com',
#   1,
#   1056.0,
#   'Sales Manager (NA)'),
#  (1165,
#   'Jennings',
#   'Leslie',
#   'x3291',
#   'ljennings@classicmodelcars.com',
#   1,
#   1143.0,
#   'Sales Rep'),
#  (1166,
#   'Thompson',
#   'Leslie',
#   'x4065',
#   'lthompson@classicmodelcars.com',
#   1,
#   1143.0,
#   'Sales Rep'),
#  (1188,
#   'Firrelli',
#   'Julie',
#   'x2173',
#   'jfirrelli@classicmodelcars.com',
#   2,
#   1143.0,
#   'Sales Rep'),
#  (1216,
#   'Patterson',
#   'Steve',
#   'x4334',
#   'spatterson@classicmodelcars.com',
#   2,
#   1143.0,
#   'Sales Rep'),
#  (1286,
#   'Tseng',
#   'Foon Yue',
#   'x2248',
#   'ftseng@classicmodelcars.com',
#   3,
#   1143.0,
#   'Sales Rep'),
#  (1323,
#   'Vanauf',
#   'George',
#   'x4102',
#   'gvanauf@classicmodelcars.com',
#   3,
#   1143.0,
#   'Sales Rep'),
#  (1337,
#   'Bondur',
#   'Loui',
#   'x6493',
#   'lbondur@classicmodelcars.com',
#   4,
#   1102.0,
#   'Sales Rep'),
#  (1370,
#   'Hernandez',
#   'Gerard',
#   'x2028',
#   'ghernande@classicmodelcars.com',
#   4,
#   1102.0,
#   'Sales Rep'),
#  (1401,
#   'Castillo',
#   'Pamela',
#   'x2759',
#   'pcastillo@classicmodelcars.com',
#   4,
#   1102.0,
#   'Sales Rep'),
#  (1501,
#   'Bott',
#   'Larry',
#   'x2311',
#   'lbott@classicmodelcars.com',
#   7,
#   1102.0,
#   'Sales Rep'),
#  (1504,
#   'Jones',
#   'Barry',
#   'x102',
#   'bjones@classicmodelcars.com',
#   7,
#   1102.0,
#   'Sales Rep'),
#  (1611,
#   'Fixter',
#   'Andy',
#   'x101',
#   'afixter@classicmodelcars.com',
#   6,
#   1088.0,
#   'Sales Rep'),
#  (1612,
#   'Marsh',
#   'Peter',
#   'x102',
#   'pmarsh@classicmodelcars.com',
#   6,
#   1088.0,
#   'Sales Rep'),
#  (1619,
#   'King',
#   'Tom',
#   'x103',
#   'tking@classicmodelcars.com',
#   6,
#   1088.0,
#   'Sales Rep'),
#  (1621,
#   'Nishi',
#   'Mami',
#   'x101',
#   'mnishi@classicmodelcars.com',
#   5,
#   1056.0,
#   'Sales Rep'),
#  (1625,
#   'Kato',
#   'Yoshimi',
#   'x102',
#   'ykato@classicmodelcars.com',
#   5,
#   1621.0,
#   'Sales Rep'),
#  (1702,
#   'Gerard',
#   'Martin',
#   'x2312',
#   'mgerard@classicmodelcars.com',
#   4,
#   1102.0,
#   'Sales Rep')]

# %%
# nuevo_orden = ["2", "1", "0", "3", "4"]
# df_pelis = df_peli.reindex(columns = nuevo_orden)

# %% [markdown]
# # Forma 1 (menos correcta)

# %%
print("INSERT INTO peliculas VALUES")
for peli in lista_tuplas_pelis:
    print(peli, ",")

# %% [markdown]
# # Forma 2 (más correcta)

# %%
import mysql.connector
from mysql.connector import errorcode

# %%
cnx = mysql.connector.connect(user = "root",
                              password = "AlumnaAdalab",
                              host = "127.0.0.1",
                              database = "proyecto_cine")#Nuesta base de datos de mysql
#Nos permite enviar informacion atraves de la conexciosm
mycursor = cnx.cursor()


#Escribimos la query aqui
#¡¡¡El ORDEN IMPORTA!!! --> El primer dato debe ser el primer elemento de la lista de tuplas
sql_pelis = "INSERT INTO peliculas (tipo, nombre, año, mes, idpeliculas, genero, imdb, roten) VALUES (%s, %s,%s, %s,%s, %s, %s,%s)" 
                        #peliculas el nombre del archivo correspondiente
try:
    mycursor,executemany(sql_pelis, lista_tuplas_premios)
    cnx.commit()
    print(mycursor.rowcount,"registros insertados")
except:
    print("Ha habido un error en la inserción")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~/anaconda3/envs/pruebalberto/lib/python3.11/site-packages/mysql/connector/connection_cext.py:308, in CMySQLConnection._open_connection(self)
#     307 try:
# --> 308     self._cmysql.connect(**cnx_kwargs)
#     309     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Unknown database 'proyecto_cine'
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# /Users/marta/Documents/adalab/modulo-2/meterdatosensql.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/Users/marta/Documents/adalab/modulo-2/meterdatosensql.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> cnx = mysql.connector.connect(user = "root",
#       <a href='vscode-notebook-cell:/Users/marta/Documents/adalab/modulo-2/meterdatosensql.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a>                               password = "AlumnaAdalab",
#       <a href='vscode-notebook-cell:/Users/marta/Documents/adalab/modulo-2/meterdatosensql.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a>                               host = "127.0.0.1",
#       <a href='vscode-notebook-cell:/Users/marta/Documents/adalab/modulo-2/meterdatosensql.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a>                               database = "proyecto_cine")#proyectocine nuesto base de datos de mysql
#       <a href='vscode-notebook-cell:/Users/marta/Documents/adalab/modulo-2/meterdatosensql.ipynb#X12sZmlsZQ%3D%3D?line=4'>5</a> #Nos permite envir informacion atraves de la conexciosm
#       <a href='vscode-notebook-cell:/Users/marta/Documents/adalab/modulo-2/meterdatosensql.ipynb#X12sZmlsZQ%3D%3D?line=5'>6</a> mycursor = cnx.cursor()
#
# File ~/anaconda3/envs/pruebalberto/lib/python3.11/site-packages/mysql/connector/pooling.py:293, in connect(*args, **kwargs)
#     290         raise ImportError(ERROR_NO_CEXT)
#     292 if CMySQLConnection and not use_pure:
# --> 293     return CMySQLConnection(*args, **kwargs)
#     294 return MySQLConnection(*args, **kwargs)
#
# File ~/anaconda3/envs/pruebalberto/lib/python3.11/site-packages/mysql/connector/connection_cext.py:129, in CMySQLConnection.__init__(self, **kwargs)
#     127 if kwargs:
#     128     try:
# --> 129         self.connect(**kwargs)
#     130     except Exception:
#     131         self.close()
#
# File ~/anaconda3/envs/pruebalberto/lib/python3.11/site-packages/mysql/connector/abstracts.py:1237, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1234     self.config(**kwargs)
#    1236 self.disconnect()
# -> 1237 self._open_connection()
#    1239 charset, collation = (
#    1240     kwargs.pop("charset", None),
#    1241     kwargs.pop("collation", None),
#    1242 )
#    1243 if charset or collation:
#
# File ~/anaconda3/envs/pruebalberto/lib/python3.11/site-packages/mysql/connector/connection_cext.py:313, in CMySQLConnection._open_connection(self)
#     311         self.converter.str_fallback = self._converter_str_fallback
#     312 except MySQLInterfaceError as err:
# --> 313     raise get_mysql_exception(
#     314         msg=err.msg, errno=err.errno, sqlstate=err.sqlstate
#     315     ) from err
#     317 self._do_handshake()
#
# ProgrammingError: 1049 (42000): Unknown database 'proyecto_cine'

# %%
#Primero eliminamos actores duplicados convirtiendolo en set que quita los repetidos
set(lista_tuplas_act)
print(len(lista_tuplas_act), len(set(lista_tuplas_act)))

# %%
lista_tuplas_act = list(set(lista_tuplas_act))
#Limpiamos corchetes y comillas antes de meter en mysql

# %%
cnx = mysql.connector.connert(user = "root",
                              password = "AlumnaAdalab",
                              hots = "127.0.0.1",
                              database = "proyecto_cine")#proyectocine nuesto base de datos de mysql
#Nos permite envir informacion atraves de la conexciosm
mycursor = cnx.cursor()


#Escribimos la query aqui
#¡El ORDEN IMPORTA!!! --> El primer dato debe ser el primer elemento de la lista de tuplas
sql_actores = "INSERT INTO actores (nombre, año_nacimiento, conocido_por, que_hace, premios) VALUES (%s, %s,%s, %s,%s)" 
                        #peliculas el nombre del archivo correspondiente
try:
    mycursor,executemany(sql_actores, lista_tuplas_act)
    cnx.commit()
    print(mycursor.rowcount,"registros insertados")
except:
    print("Ha habido un error en la inserción")
