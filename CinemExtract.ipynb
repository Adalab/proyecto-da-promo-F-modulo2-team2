# %%
import requests

url = "https://moviesdatabase.p.rapidapi.com/titles"
#Genero en mayúscula la primera!
lista_generos =["Drama", "Comedy", "Action", "Fantasy", "Horror", "Mystery", "Romance", "Thriller"]

for genero in lista_generos:
    
    for n in range(1,51):
        querystring = {"genre":f"{genero}","startYear":"1990", "page":f"{n}"}
 

    headers = {
        "X-RapidAPI-Key": "c3c38e4e73msh8d035fe2c260329p120d52jsn12bffab245aa",
        "X-RapidAPI-Host": "moviesdatabase.p.rapidapi.com"}

    response = requests.get(url, headers=headers, params=querystring)
    json_response = response.json()
print(json_response)
# Out:
# {'page': '50', 'next': '/titles?page=61e59b34a66e5964234786c3&startYear=1990&genre=Thriller', 'entries': 10, 'results': [{'_id': '61e599c4cffb8f2faa472a91', 'id': 'tt12476674', 'primaryImage': {'id': 'rm4123012609', 'width': 1200, 'height': 1800, 'url': 'https://m.media-amazon.com/images/M/MV5BOWViODQzODctYzgxOC00YjY2LWE3MjctN2NhZWYzYTQ3Y2Y1XkEyXkFqcGdeQXVyNTcwMzkyNDE@._V1_.jpg', 'caption': {'plainText': 'Elena Ontiveros, Jackson Lee Turner, Warren McLemore, and Brandon McLemore in Dark Entities (2023)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'displayableProperty': {'value': {'plainText': '', '__typename': 'Markdown'}, '__typename': 'DisplayableTitleTypeProperty'}, 'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Dark Entities', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Dark Entities', '__typename': 'TitleText'}, 'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 14, 'month': 4, 'year': 2023, '__typename': 'ReleaseDate'}}, {'_id': '61e599e0e1a8ddbd9647327f', 'id': 'tt12494932', 'primaryImage': {'id': 'rm997048577', 'width': 592, 'height': 885, 'url': 'https://m.media-amazon.com/images/M/MV5BZTI0Yzg5NzctNjRjNC00NmRlLTk0MWQtNzk5ZGFkOGM5NDliXkEyXkFqcGdeQXVyODM0NDIyMDI@._V1_.jpg', 'caption': {'plainText': '72 (2023)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'displayableProperty': {'value': {'plainText': '', '__typename': 'Markdown'}, '__typename': 'DisplayableTitleTypeProperty'}, 'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': '72', '__typename': 'TitleText'}, 'originalTitleText': {'text': '72', '__typename': 'TitleText'}, 'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 23, 'month': 6, 'year': 2023, '__typename': 'ReleaseDate'}}, {'_id': '61e59a548a5a6a599f4751a9', 'id': 'tt12573454', 'primaryImage': {'id': 'rm781729025', 'width': 1000, 'height': 1500, 'url': 'https://m.media-amazon.com/images/M/MV5BM2JlN2Q2ZmYtYmU4OS00ZjNlLWE2OTEtOTc2ZDY5NjEwMTM4XkEyXkFqcGdeQXVyMTEyMjM2NDc2._V1_.jpg', 'caption': {'plainText': 'Julianne Moore, John Lithgow, Sebastian Stan, Justice Smith, and Briana Middleton in Sharper (2023)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'displayableProperty': {'value': {'plainText': '', '__typename': 'Markdown'}, '__typename': 'DisplayableTitleTypeProperty'}, 'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Sharper', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Sharper', '__typename': 'TitleText'}, 'releaseYear': {'year': 2023, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 17, 'month': 2, 'year': 2023, '__typename': 'ReleaseDate'}}, {'_id': '61e59aeb78c012aa34477143', 'id': 'tt12675384', 'primaryImage': {'id': 'rm4049251841', 'width': 1364, 'height': 2048, 'url': 'https://m.media-amazon.com/images/M/MV5BZmZjZTA1NWEtZjc2OS00NjU1LTlkZjItMGE0YTllY2Y1ODU1XkEyXkFqcGdeQXVyNTA3MzY0NzM@._V1_.jpg', 'caption': {'plainText': 'Total Paranoia (2023)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'displayableProperty': {'value': {'plainText': '', '__typename': 'Markdown'}, '__typename': 'DisplayableTitleTypeProperty'}, 'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Total Paranoia', '__typename': 'TitleText'}, 'originalTi ...

# %%
json_response["next"]
# Out:
# '/titles?page=61e59b34a66e5964234786c3&startYear=1990&genre=Thriller'

# %%
lista_generos =["Drama", "Comedy", "Action", "Fantasy", "Horror", "Mystery", "Romance", "Thriller"]

for genero in lista_generos:
    for n in range(1,51):
        querystring1 = {"genre":f"{genero}","startYear":"1990", "page":f"{n}"}
        print (querystring1)
# Out:
# {'genre': 'Drama', 'startYear': '1990', 'page': '1'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '2'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '3'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '4'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '5'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '6'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '7'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '8'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '9'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '10'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '11'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '12'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '13'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '14'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '15'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '16'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '17'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '18'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '19'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '20'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '21'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '22'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '23'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '24'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '25'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '26'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '27'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '28'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '29'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '30'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '31'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '32'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '33'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '34'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '35'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '36'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '37'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '38'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '39'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '40'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '41'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '42'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '43'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '44'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '45'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '46'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '47'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '48'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '49'}
# {'genre': 'Drama', 'startYear': '1990', 'page': '50'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '1'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '2'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '3'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '4'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '5'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '6'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '7'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '8'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '9'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '10'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '11'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '12'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '13'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '14'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '15'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '16'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '17'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '18'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '19'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '20'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '21'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '22'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '23'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '24'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '25'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '26'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '27'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '28'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '29'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '30'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '31'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '32'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '33'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '34'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '35'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '36'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '37'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '38'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '39'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '40'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '41'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '42'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '43'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '44'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '45'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '46'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '47'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '48'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '49'}
# {'genre': 'Comedy', 'startYear': '1990', 'page': '50'}
# {'genre': 'Action', 'startYear': '1990', 'page': '1'}
# {'genre': 'Action', 'startYear': '1990', 'page': '2'}
# {'genre': 'Action', 'startYear': '1990', 'page': '3'}
# {'genre': 'Action', 'startYear': '1990', 'page': '4'}
# {'genre': 'Action', 'startYear': '1990', 'page': '5'}
# {'genre': 'Action', 'startYear': '1990', 'page': '6'}
# {'genre': 'Action', 'startYear': '1990', 'page': '7'}
# {'genre': 'Action', 'startYear': '1990', 'page': '8'}
# {'genre': 'Action', 'startYear': '1990', 'page': '9'}
# {'genre': 'Action', 'startYear': '1990', 'page': '10'}
# {'genre': 'Action', 'startYear': '1990', 'page': '11'}
# {'genre': 'Action', 'startYear': '1990', 'page': '12'}
# {'genre': 'Action', 'startYear': '1990', 'page': '13'}
# {'genre': 'Action', 'startYear': '1990', 'page': '14'}
# {'genre': 'Action', 'startYear': '1990', 'page': '15'}
# {'genre': 'Action', 'startYear': '1990', 'page': '16'}
# {'genre': 'Action', 'startYear': '1990', 'page': '17'}
# {'genre': 'Action', 'startYear': '1990', 'page': '18'}
# {'genre': 'Action', 'startYear': '1990', 'page': '19'}
# {'genre': 'Action', 'startYear': '1990', 'page': '20'}
# {'genre': 'Action', 'startYear': '1990', 'page': '21'}
# {'genre': 'Action', 'startYear': '1990', 'page': '22'}
# {'genre': 'Action', 'startYear': '1990', 'page': '23'}
# {'genre': 'Action', 'startYear': '1990', 'page': '24'}
# {'genre': 'Action', 'startYear': '1990', 'page': '25'}
# {'genre': 'Action', 'startYear': '1990', 'page': '26'}
# {'genre': 'Action', 'startYear': '1990', 'page': '27'}
# {'genre': 'Action', 'startYear': '1990', 'page': '28'}
# {'genre': 'Action', 'startYear': '1990', 'page': '29'}
# {'genre': 'Action', 'startYear': '1990', 'page': '30'}
# {'genre': 'Action', 'startYear': '1990', 'page': '31'}
# {'genre': 'Action', 'startYear': '1990', 'page': '32'}
# {'genre': 'Action', 'startYear': '1990', 'page': '33'}
# {'genre': 'Action', 'startYear': '1990', 'page': '34'}
# {'genre': 'Action', 'startYear': '1990', 'page': '35'}
# {'genre': 'Action', 'startYear': '1990', 'page': '36'}
# {'genre': 'Action', 'startYear': '1990', 'page': '37'}
# {'genre': 'Action', 'startYear': '1990', 'page': '38'}
# {'genre': 'Action', 'startYear': '1990', 'page': '39'}
# {'genre': 'Action', 'startYear': '1990', 'page': '40'}
# {'genre': 'Action', 'startYear': '1990', 'page': '41'}
# {'genre': 'Action', 'startYear': '1990', 'page': '42'}
# {'genre': 'Action', 'startYear': '1990', 'page': '43'}
# {'genre': 'Action', 'startYear': '1990', 'page': '44'}
# {'genre': 'Action', 'startYear': '1990', 'page': '45'}
# {'genre': 'Action', 'startYear': '1990', 'page': '46'}
# {'genre': 'Action', 'startYear': '1990', 'page': '47'}
# {'genre': 'Action', 'startYear': '1990', 'page': '48'}
# {'genre': 'Action', 'startYear': '1990', 'page': '49'}
# {'genre': 'Action', 'startYear': '1990', 'page': '50'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '1'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '2'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '3'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '4'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '5'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '6'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '7'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '8'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '9'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '10'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '11'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '12'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '13'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '14'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '15'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '16'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '17'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '18'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '19'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '20'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '21'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '22'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '23'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '24'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '25'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '26'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '27'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '28'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '29'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '30'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '31'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '32'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '33'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '34'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '35'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '36'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '37'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '38'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '39'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '40'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '41'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '42'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '43'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '44'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '45'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '46'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '47'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '48'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '49'}
# {'genre': 'Fantasy', 'startYear': '1990', 'page': '50'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '1'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '2'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '3'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '4'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '5'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '6'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '7'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '8'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '9'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '10'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '11'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '12'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '13'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '14'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '15'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '16'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '17'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '18'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '19'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '20'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '21'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '22'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '23'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '24'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '25'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '26'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '27'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '28'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '29'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '30'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '31'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '32'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '33'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '34'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '35'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '36'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '37'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '38'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '39'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '40'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '41'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '42'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '43'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '44'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '45'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '46'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '47'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '48'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '49'}
# {'genre': 'Horror', 'startYear': '1990', 'page': '50'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '1'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '2'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '3'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '4'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '5'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '6'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '7'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '8'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '9'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '10'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '11'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '12'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '13'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '14'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '15'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '16'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '17'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '18'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '19'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '20'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '21'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '22'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '23'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '24'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '25'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '26'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '27'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '28'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '29'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '30'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '31'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '32'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '33'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '34'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '35'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '36'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '37'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '38'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '39'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '40'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '41'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '42'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '43'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '44'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '45'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '46'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '47'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '48'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '49'}
# {'genre': 'Mystery', 'startYear': '1990', 'page': '50'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '1'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '2'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '3'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '4'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '5'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '6'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '7'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '8'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '9'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '10'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '11'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '12'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '13'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '14'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '15'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '16'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '17'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '18'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '19'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '20'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '21'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '22'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '23'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '24'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '25'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '26'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '27'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '28'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '29'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '30'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '31'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '32'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '33'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '34'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '35'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '36'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '37'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '38'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '39'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '40'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '41'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '42'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '43'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '44'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '45'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '46'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '47'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '48'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '49'}
# {'genre': 'Romance', 'startYear': '1990', 'page': '50'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '1'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '2'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '3'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '4'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '5'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '6'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '7'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '8'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '9'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '10'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '11'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '12'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '13'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '14'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '15'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '16'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '17'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '18'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '19'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '20'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '21'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '22'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '23'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '24'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '25'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '26'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '27'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '28'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '29'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '30'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '31'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '32'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '33'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '34'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '35'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '36'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '37'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '38'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '39'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '40'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '41'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '42'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '43'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '44'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '45'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '46'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '47'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '48'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '49'}
# {'genre': 'Thriller', 'startYear': '1990', 'page': '50'}

# %%
response.status_code

# %%
json_response.keys()

# %%
json_response["results"]

# %%
len(json_response["results"])

# %%
json_response["results"][-5]

# %%
json_response["results"][-5].keys()

# %%
json_response["results"][-1]['id']

# %%
json_response["results"][-5]['releaseDate']

# %%
json_response["results"][-5]['releaseDate']["year"]

# %%
json_response["results"][-5]['releaseDate']["month"]

# %%
json_response["results"][-5]['titleType']["text"]

# %%
json_response["results"][-5]['titleText']["text"]

# %%
#Tipo (si es corto o película).
#Nombre de la película o el corto.
#Año de estreno de la película o corto.
#Mes de estreno de la película o corto.
#Id de la película. 'id': 'tt28621251',

# %%
json_response["results"][0].keys()

# %%
lista_peliculas = []
for peli in json_response["results"]:
    lista_todas_pelis = []
    tipo_peli = peli['titleType']["text"]
    nombre_peli = peli['titleText']["text"]
    id_peli =peli['id']
    lista_todas_pelis.append(tipo_peli)
    lista_todas_pelis.append(nombre_peli)
    lista_todas_pelis.append(id_peli)
    try: 
        mes_estreno_peli = peli["releaseDate"]["month"]
    except:
        mes_estreno_peli = ''
    lista_todas_pelis.append(mes_estreno_peli)
    try:
        ano_estreno_peli = peli["releaseDate"]["year"]
    except:
        ano_estreno_peli = ''
    lista_todas_pelis.append(ano_estreno_peli)
    lista_peliculas.append(tuple(lista_todas_pelis))
print(lista_peliculas)
print(lista_peliculas[0])

# %%
lista_generos =["Drama", "Comedy", "Action", "Fantasy", "Horror", "Mystery", "Romance", "Thriller"]

for genero in lista_generos:
    querystring = {"genre":f"{genero}","startYear":"1990", "page": "1", "limit":"50"}

    print (querystring1)
